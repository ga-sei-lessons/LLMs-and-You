# %% [markdown]
# **Debugging Code with AI**
#
# Below, you will find 5 pieces of Python code that are bugged in some way. Your task is to fix the code to the best of your ability, with help from ChatGPT.
#
# The problems are intended to get progressively more complex, but do your best to fix as many as you can in 10 minutes!

# %% [markdown]
# # 1

# %%
#1 Good old foobar!
def foo(bar=[]):        # bar is optional and defaults to [] if not specified
  bar.append("baz")
  return bar
print(foo())
print(foo())
print(foo())
# Out:
# ['baz']
# ['baz', 'baz']
# ['baz', 'baz', 'baz']

# %% [markdown]
# When you run the code above, the expected output is as follows:
# ```
# >>> foo()
# ["baz"]
# >>> foo()
# ["baz"]
# >>> foo()
# ["baz"]
# ```
# But this is not what you're getting, is it? Can you fix it?

# %% [markdown]
# # 2

# %%
#2 Calculate factorial of an integer recursively

def factorial(n):
    if n == 0:
        return 1
    else:
        return n * factorial(n - 1)

# %% [markdown]
# In Problem 2, an obvious edge case has been overlooked. Can you and/or ChatGPT find it?

# %% [markdown]
# # 3

# %%
#3 Another foo!

x = 10

def foo():
  x += 1
  print(x)

# %% [markdown]
# Calling ```foo()``` will raise an ```UnboundedLocalError``` exception. Why? Can you fix it?

# %% [markdown]
# # 4

# %%
#4 Let's assume we have a list of numbers and we want to remove the odd numbers. This is what the following code snippet does (or does it?).

odd = lambda x: bool(x%2) # check if a number is odd

numbers = [n for n in range(10)]

for i in range(len(numbers)):
  if odd(numbers[i]):
    del numbers[i]

# %% [markdown]
# Running the above snippet will raise an ```IndexError``` exception. Why?

# %% [markdown]
# # 5

# %%
#5 Simple array of lambda functions that is used to calculate the addition of a number on the fly.

def lambda_array():
    # initialize an empty array
    lambda_methods = []
    # implement a for loop to count from 0 to 9
    for i in range(10):
        # append the lambda function to the array defined above
        #lambda_methods.append(lambda x: x + i)
        lambda_methods.append(lambda x, i = i : x + i)

    return lambda_methods

# %% [markdown]
# The following code should return 10:
# ```
# lambdas = lambda_array()
# lambdas[0](10)
# ```
# But it returns 19. Why? Fix the code.
